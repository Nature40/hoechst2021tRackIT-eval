# %%
import pandas

# %%
df = pandas.read_csv("compression_onedevice.csv")
df = df.set_index("batchsize")
df = df.drop("cbor", axis=1)
df
# Out:
#                lzma      zlib       lz4      zstd    brotli
# batchsize
# 1          2.311111  1.244444  1.511111  1.200000  1.088889
# 2          1.567010  1.010309  1.175258  1.030928  1.041237
# 3          1.234899  0.838926  0.966443  0.845638  0.912752
# 4          1.056995  0.772021  0.891192  0.777202  0.849741
# 5          0.950192  0.727969  0.827586  0.739464  0.770115
# 6          0.856230  0.680511  0.779553  0.686901  0.706070
# 7          0.810959  0.652055  0.736986  0.654795  0.706849
# 8          0.786571  0.647482  0.733813  0.647482  0.717026
# 9          0.742004  0.622601  0.705757  0.618337  0.703625
# 10         0.715084  0.616387  0.694600  0.610801  0.597765
# 20         0.585275  0.556384  0.625349  0.512582  0.505126
# 30         0.521957  0.518821  0.583438  0.463614  0.470514
# 40         0.497670  0.509786  0.571761  0.448276  0.454800
# 50         0.475619  0.489122  0.555889  0.432108  0.438485
# ...

# %%
df.plot(figsize=(16,8), xlabel="Batch Size (count)", ylabel="Compression Ratio", title="tRackIT Batched Compression Benchmark", logy=True)
# Out:
# <AxesSubplot:title={'center':'tRackIT Batched Compression Benchmark'}, xlabel='Batch Size (count)', ylabel='Compression Ratio'>
